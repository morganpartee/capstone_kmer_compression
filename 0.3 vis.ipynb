# %%
import pandas as pd
import seaborn as sns
from datetime import datetime

# %%
results = pd.read_csv("0.3.csv", header=None, names = ["Token Size", "K-Size", "Initial Features", "Resultant Features", "Accuracy", "SD", "Detailed_Results","Start Time", "End Time"])
results['Start Time'] = results['Start Time'].apply(lambda x: datetime.fromisoformat(x[1:]))
results['End Time'] = results['End Time'].apply(lambda x: datetime.fromisoformat(x[1:]))
results['Duration'] = (results['End Time'] - results['Start Time']).apply(lambda x: x.seconds/60)

# %%
results.head()
# Out:
#    Token Size  K-Size  Initial Features  Resultant Features  Accuracy  \
# 0           1       8             36695               22978  0.869103
# 1           1       9            132647               24159  0.884359
# 2           1      10            532738               20759  0.879231
# 3           1      11           1543571               16096  0.889231
# 4           1      12           3280387               12386  0.911923
#
#          SD                                   Detailed_Results  \
# 0  0.029036   [0.825      0.875      0.875      0.875      ...
# 1  0.033452   [0.85       0.875      0.875      0.925      ...
# 2  0.041414   [0.8        0.9        0.875      0.925      ...
# 3  0.039204   [0.875      0.925      0.875      0.925      ...
# 4  0.022893   [0.925      0.925      0.9        0.925      ...
#
#                   Start Time                   End Time    Duration
# 0 2020-07-07 11:10:42.359740 2020-07-07 12:03:20.765885   52.633333
# 1 2020-07-07 12:03:20.765893 2020-07-07 13:00:06.480387   56.750000
# 2 2020-07-07 13:00:06.480397 2020-07-07 14:10:29.337356   70.366667
# 3 2020-07-07 14:10:29.337365 2020-07-07 15:43:06.863080   92.616667
# 4 2020-07-07 15:43:06.863088 2020-07-07 17:49:42.528877  126.583333

# %%
sns.set_style("whitegrid")
sns.lineplot(x='K-Size', y='Accuracy', hue="Token Size", data=results, palette="deep")

# %%
sns.lineplot(x='K-Size', y='Duration', hue="Token Size", data=results, palette="deep")

# %%
sns.lineplot(x='K-Size', y='Initial Features', hue="Token Size", data=results, palette="deep")

# %%
sns.lineplot(x='K-Size', y='Resultant Features', hue="Token Size", data=results, palette="deep")
